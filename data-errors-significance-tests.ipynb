# %%
# Import jupysql Jupyter extension to create SQL cells
# %load_ext sql

# Configure jupysql to return data as a Pandas dataframe and have less verbose output
# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False

# Connect jupysql to in-memory DuckDB database
# %sql duckdb:///:memory:

# %%
import duckdb

# %%
from demodq.analysis import is_disparate

# %%
filtered_errors = %sql SELECT * FROM cleanml_errors.csv WHERE (attr2 != 'age@55') AND NOT (dataset = 'german' AND attr1='sex')

# %%
# %sql SELECT * from cleanml_groups.csv
# Out:
#       dataset attr1           attr2  pp_count  pd_count  dp_count  dd_count
# 0       adult   sex            race     28735      3915     13027      3165
# 1  folktables   sex            race    115136     71541    117473     74667
# 2       heart   sex          age@45     39163      6367     20565      3905
# 3       heart   sex          age@55     20579     10674     24951     13796
# 4      german   age             sex       605       205        85       105
# 5      german   age  foreign_worker        34       776         3       187
# 6      german   sex  foreign_worker        30       660         7       303

# %%
errors_and_counts = %sql SELECT f.dataset, f.attr1, f.attr2, error_type, pp_dirty, dd_dirty, pp_count, dd_count \
FROM filtered_errors AS f, cleanml_groups.csv AS g \
WHERE f.dataset = g.dataset AND f.attr1=g.attr1 AND f.attr2=g.attr2

# %%
errors_and_counts
# Out:
#        dataset attr1           attr2      error_type  pp_dirty  dd_dirty  \
# 0        adult   sex            race  missing-values      1715       353
# 1   folktables   sex            race  missing-values     50027     38371
# 2        heart   sex          age@45  missing-values         0         0
# 3       german   age             sex  missing-values       208        21
# 4       german   age  foreign_worker  missing-values         8        38
# 5        adult   sex            race     outliers-sd      2321       119
# 6        adult   sex            race    outliers-iqr     10694       982
# 7        adult   sex            race     outliers-if        16       281
# 8   folktables   sex            race     outliers-sd       801       312
# 9   folktables   sex            race    outliers-iqr         0         0
# 10  folktables   sex            race     outliers-if       299      1663
# 11       heart   sex          age@45     outliers-sd      4249       267
# 12       heart   sex          age@45    outliers-iqr      9524       705
# 13       heart   sex          age@45     outliers-if       172        91
# 14      german   age             sex     outliers-sd        33         2
# 15      german   age             sex    outliers-iqr       209        11
# 16      german   age             sex     outliers-if         6         1
# 17      german   age  foreign_worker     outliers-sd         2         7
# 18      german   age  foreign_worker    outliers-iqr        13        27
# 19      german   age  foreign_worker     outliers-if         3         0
# 20       adult   sex            race    mislabels-cl      2956       111
# 21  folktables   sex            race    mislabels-cl      9231      3828
# 22       heart   sex          age@45    mislabels-cl      8793       790
# 23      german   age             sex    mislabels-cl       134        22
# 24      german   age  foreign_worker    mislabels-cl         6        68
#
#     pp_count  dd_count
# 0      28735      3165
# 1     115136     74667
# 2      39163      3905
# 3        605       105
# 4         34       187
# 5      28735      3165
# 6      28735      3165
# 7      28735      3165
# 8     115136     74667
# 9     115136     74667
# 10    115136     74667
# 11     39163      3905
# 12     39163      3905
# 13     39163      3905
# 14       605       105
# 15       605       105
# 16       605       105
# 17        34       187
# 18        34       187
# 19        34       187
# 20     28735      3165
# 21    115136     74667
# 22     39163      3905
# 23       605       105
# 24        34       187

# %%
for et in ['missing-values', 'outliers-sd', 'outliers-iqr', 'outliers-if', 'mislabels-cl']:
    
    ratios_pp = []
    ratios_dd = []
    
    counts = errors_and_counts[errors_and_counts.error_type==et]
    for _, row in counts.iterrows():
        dataset = row['dataset']
        attr1 = row['attr1']
        attr2 = row['attr2']
        error_type = row['error_type']

        num_pp = row['pp_count']
        num_dd = row['dd_count']
        dirty_pp = row['pp_dirty']
        dirty_dd = row['dd_dirty']

        #disparate = is_disparate(len(data_priv), len(dirty_priv), len(data_nonpriv), len(dirty_nonpriv))
        disparate = is_disparate(num_pp, dirty_pp , num_dd, dirty_dd)

        if disparate:
            ratios_pp.append(dirty_pp/num_pp * 100)
            ratios_dd.append(dirty_dd/num_dd * 100)            
        else:
            ratios_pp.append(0.0)
            ratios_dd.append(0.0)     
        print('#', dataset, attr1, attr2, error_type, disparate)

    print('#----')  
    print(f"{et.replace('-', '_')}_pp", '=', ratios_pp)
    print(f"{et.replace('-', '_')}_dd", '=', ratios_dd)
    print('#----')
# Out:
# # adult sex race missing-values True
# # folktables sex race missing-values True
# # heart sex age@45 missing-values False
# # german age sex missing-values True
# # german age foreign_worker missing-values False
# #----
# missing_values_pp = [5.9683313032886725, 43.4503543635353, 0.0, 34.3801652892562, 0.0]
# missing_values_dd = [11.153238546603475, 51.38950272543427, 0.0, 20.0, 0.0]
# #----
# # adult sex race outliers-sd True
# # folktables sex race outliers-sd True
# # heart sex age@45 outliers-sd True
# # german age sex outliers-sd False
# # german age foreign_worker outliers-sd False
# #----
# outliers_sd_pp = [8.077257699669392, 0.6956989994441356, 10.849526338635958, 0.0, 0.0]
# outliers_sd_dd = [3.7598736176935232, 0.4178552774317972, 6.837387964148528, 0.0, 0.0]
# #----
# # adult sex race outliers-iqr True
# # folktables sex race outliers-iqr False
# # heart sex age@45 outliers-iqr True
# # german age sex outliers-iqr True
# # german age foreign_worker outliers-iqr True
# #----
# outliers_iqr_pp = [37.21593875065252, 0.0, 24.31887240507622, 34.54545454545455, 38.23529411764706]
# outliers_iqr_dd = [31.02685624012638, 0.0, 18.053777208706787, 10.476190476190476, 14.43850267379679]
# #----
# # adult sex race outliers-if True
# # folktables sex race outliers-if True
# # heart sex age@45 outliers-if True
# # german age sex outliers-if False
# # german age foreign_worker outliers-if True
# #----
# outliers_if_pp = [0.05568122498694971, 0.25969288493607556, 0.4391900518346399, 0.0, 8.823529411764707]
# outliers_if_dd = [8.878357030015797, 2.2272221999008934, 2.330345710627401, 0.0, 0.0]
# #----
# # adult sex race mislabels-cl True
# # folktables sex race mislabels-cl True
# # heart sex age@45 mislabels-cl True
# # german age sex mislabels-cl False
# # german age foreign_worker mislabels-cl True
# #----
# mislabels_cl_pp = [10.28710631633896, 8.017474986103391, 22.452314684779, 0.0, 17.647058823529413]
# mislabels_cl_dd = [3.5071090047393367, 5.126762826951666, 20.23047375160051, 0.0, 36.36363636363637]
# #----
